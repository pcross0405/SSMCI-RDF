# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc

import particle_rdfMP as prm

# %%
rdfCalculator = prm.RDFCalculator()

# %%
filename = r"Z:\Current Group Members\Tyler Knapp\SSMC\MDSimulations\DeepQuench\15box-15A-cool1_5\Positions.dump"
frames = [x*1000 for x in range(0, 5)]
targetID = 1169
maxRange = 20

rdfCalculator.FileTrawler(filename, frames, targetID, maxRange)
# Out:
# 2026-02-18 15:38:07,672 - distributed.protocol.pickle - ERROR - Failed to serialize <ToPickle: HighLevelGraph with 1 layers.
# ...
#  0. 2152128296000
# >.
# Traceback (most recent call last):
#   File "C:\Users\tyler\miniconda3\envs\General\Lib\site-packages\distributed\protocol\pickle.py", line 63, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: cannot pickle '_asyncio.Task' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tyler\miniconda3\envs\General\Lib\site-packages\distributed\protocol\pickle.py", line 68, in dumps
#     pickler.dump(x)
# TypeError: cannot pickle '_asyncio.Task' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tyler\miniconda3\envs\General\Lib\site-packages\distributed\protocol\pickle.py", line 81, in dumps
# ...
