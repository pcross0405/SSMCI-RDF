# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc

import src.particle_rdfMP as prm

# %%
filename = r"Z:\Current Group Members\Tyler Knapp\SSMC\MDSimulations\DeepQuench\15box-15A-cool1_5\Positions.dump"
frames = [x*1000 for x in range(0, 10)]
targetID = 1169
maxRange = 20

rdfCalculator = prm.RDFCalculator(filename, frames, targetID, maxRange)

rdfData = rdfCalculator.FileScanner()

# print(rdfCalculator.futureResults)
# Out:
# 100.00% complete

# %%
plt.plot(rdfCalculator.x, rdfData[-1])
